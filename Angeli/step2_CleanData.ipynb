# %%
#notebook for reading csv, cleaning data

# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import pandas as pd
import scipy.stats as sts
import numpy as np
import datetime

# %%
all_states_history_path = "Resources/all-states-history.csv"
national_history_path = "Resources/national-history.csv"

all_states_history = pd.read_csv(all_states_history_path)
national_history = pd.read_csv(national_history_path)
# Out:
# /Users/Angeli/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
all_states_history.head()
# Out:
#          date state dataQualityGrade   death  deathConfirmed  deathIncrease  \
# 0  2021-01-04    AK                A   218.0           218.0              3
# 1  2021-01-04    AL                A  4878.0          4259.0              5
# 2  2021-01-04    AR               A+  3800.0          3178.0             51
# 3  2021-01-04    AS                D     0.0             NaN              0
# 4  2021-01-04    AZ               A+  9064.0          8173.0              3
#
#    deathProbable  hospitalized  hospitalizedCumulative  hospitalizedCurrently  \
# 0            NaN        1033.0                  1033.0                   97.0
# 1          619.0       35430.0                 35430.0                 3064.0
# 2          622.0       11514.0                 11514.0                 1296.0
# 3            NaN           NaN                     NaN                    NaN
# 4          891.0       39897.0                 39897.0                 4647.0
#
# ...

# %%
#extract columns for date, state,

# %%
all_states_rev = all_states_history[["date","state","positive","totalTestResults"]]
all_states_rev.head(20)
# Out:
#           date state   positive  totalTestResults
# 0   2021-01-04    AK    46812.0         1297498.0
# 1   2021-01-04    AL   374095.0         1903388.0
# 2   2021-01-04    AR   234781.0         2095621.0
# 3   2021-01-04    AS        0.0            2140.0
# 4   2021-01-04    AZ   561542.0         5288658.0
# 5   2021-01-04    CA  2420894.0        34127013.0
# 6   2021-01-04    CO   343435.0         4529774.0
# 7   2021-01-04    CT   194636.0         4468860.0
# 8   2021-01-04    DC    29904.0          921119.0
# 9   2021-01-04    DE    60333.0         1004179.0
# 10  2021-01-04    FL  1352222.0        16095888.0
# 11  2021-01-04    GA   591106.0         5482790.0
# 12  2021-01-04    GU     7344.0           96836.0
# 13  2021-01-04    HI    22527.0          828410.0
# 14  2021-01-04    IA   242808.0         1179621.0
# 15  2021-01-04    ID   142507.0          549099.0
# 16  2021-01-04    IL   984880.0        13530371.0
# 17  2021-01-04    IN   529688.0         5814026.0
# ...

# %%
#format date column

month_lst = []

date_column = all_states_rev["date"]
date_column.head()
for x in date_column:
    lst = x.split('-')
    month = lst[1]
    month_lst.append(month)

all_states_monthly = pd.DataFrame(data= all_states_rev)

all_states_monthly['Month'] = month_lst
all_states_group = all_states_monthly.groupby('Month').count()
all_states_group
# Out:
#        date  state  positive  totalTestResults
# Month
# 01      256    256       245               247
# 02      128    128        58               128
# 03     1483   1483      1410              1423
# 04     1680   1680      1680              1680
# 05     1736   1736      1736              1736
# 06     1680   1680      1680              1680
# 07     1736   1736      1736              1736
# 08     1736   1736      1736              1736
# 09     1680   1680      1680              1680
# 10     1736   1736      1736              1736
# 11     1680   1680      1680              1680
# 12     1736   1736      1736              1736

# %%
#group by state

all_states_group = all_states_col.groupby(["state"])
all_states_group.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-58e5aead4a1f> in <module>
#       1 #group by state
#       2
# ----> 3 all_states_group = all_states_col.groupby(["state"])
#       4 all_states_group.head()
#
# NameError: name 'all_states_col' is not defined

# %%
#
