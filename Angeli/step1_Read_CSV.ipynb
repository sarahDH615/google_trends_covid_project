# %%
#notebook for reading csv

# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import pandas as pd
import scipy.stats as sts
import numpy as np
import datetime

# %%
all_states_history_path = "Resources/all-states-history.csv"
national_history_path = "Resources/national-history.csv"

all_states_history = pd.read_csv(all_states_history_path)
national_history = pd.read_csv(national_history_path)

# %%
all_states_history.head()
# Out:
#          date state dataQualityGrade   death  deathConfirmed  deathIncrease  \
# 0  2020-12-18    AK                A   183.0           183.0              0
# 1  2020-12-18    AL                A  4296.0          3772.0             42
# 2  2020-12-18    AR               A+  3139.0          2776.0             27
# 3  2020-12-18    AS                D     0.0             NaN              0
# 4  2020-12-18    AZ               A+  7819.0          7142.0            142
#
#    deathProbable  hospitalized  hospitalizedCumulative  hospitalizedCurrently  \
# 0            NaN         928.0                   928.0                  142.0
# 1          524.0       30224.0                 30224.0                 2447.0
# 2          363.0       10430.0                 10430.0                 1073.0
# 3            NaN           NaN                     NaN                    NaN
# 4          677.0       32293.0                 32293.0                 3931.0
#
# ...

# %%
national_history.head()
# Out:
#          date     death  deathIncrease  inIcuCumulative  inIcuCurrently  \
# 0  2020-12-18  305127.0           2866          34716.0         21745.0
# 1  2020-12-17  302261.0           3438          34485.0         21910.0
# 2  2020-12-16  298823.0           3448          34237.0         21946.0
# 3  2020-12-15  295375.0           2971          33958.0         21882.0
# 4  2020-12-14  292404.0           1358          33693.0         21456.0
#
#    hospitalizedIncrease  hospitalizedCurrently  hospitalizedCumulative  \
# 0                  5240               114685.0                638147.0
# 1                  5133               114195.0                632907.0
# 2                  4800               113066.0                627774.0
# 3                  4398               112814.0                622974.0
# 4                  3569               110549.0                618576.0
#
#       negative  negativeIncrease  onVentilatorCumulative  \
# ...
