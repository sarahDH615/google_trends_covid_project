# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import pandas as pd
import scipy.stats as sts
import numpy as np
import datetime

# %%
all_states_history_path = "data/all-states-history.csv"
national_history_path = "data/national-history.csv"

all_states_history = pd.read_csv(all_states_history_path)
national_history = pd.read_csv(national_history_path)

all_states_history

#make new df
#all_states_history_df[all_states_history]
#date, state, postivies, total, hospitalized, recovered v death

#group date by month 
#on ventilator currently v hospitalized currently  

#hospitals by states to compare between states 
#hospitalizations and ventilators
# Out:
#              date state dataQualityGrade   death  deathConfirmed  \
# 0      2020-12-18    AK                A   183.0           183.0
# 1      2020-12-18    AL                A  4296.0          3772.0
# 2      2020-12-18    AR               A+  3139.0          2776.0
# 3      2020-12-18    AS                D     0.0             NaN
# 4      2020-12-18    AZ               A+  7819.0          7142.0
# ...           ...   ...              ...     ...             ...
# 16310  2020-01-17    WA              NaN     NaN             NaN
# 16311  2020-01-16    WA              NaN     NaN             NaN
# 16312  2020-01-15    WA              NaN     NaN             NaN
# 16313  2020-01-14    WA              NaN     NaN             NaN
# 16314  2020-01-13    WA              NaN     NaN             NaN
#
#        deathIncrease  deathProbable  hospitalized  hospitalizedCumulative  \
# 0                  0            NaN         928.0                   928.0
# ...

# %%
national_history.dtypes

#national_history

#hospitalized vs. ventilator 
#input state to generate chart
# Out:
# date                         object
# death                       float64
# deathIncrease                 int64
# inIcuCumulative             float64
# inIcuCurrently              float64
# hospitalizedIncrease          int64
# hospitalizedCurrently       float64
# hospitalizedCumulative      float64
# negative                    float64
# negativeIncrease              int64
# onVentilatorCumulative      float64
# onVentilatorCurrently       float64
# positive                    float64
# positiveIncrease              int64
# recovered                   float64
# states                        int64
# totalTestResults              int64
# totalTestResultsIncrease      int64
# dtype: object

# %%
national_history['month'] = national_history['date'].dt.strftime('%Y-%m')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-3b427bdfd687> in <module>
# ----> 1 national_history['month'] = national_history['date'].dt.strftime('%Y-%m')
#       2
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5268             or name in self._accessors
#    5269         ):
# -> 5270             return object.__getattribute__(self, name)
#    5271         else:
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     185             # we're accessing the attribute of the class, i.e., Dataset.geo
#     186             return self._accessor
# --> 187         accessor_obj = self._accessor(obj)
#     188         # Replace the property with the accessor object. Inspired by:
# ...
