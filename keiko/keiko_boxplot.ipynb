# %%
#dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#reading in the state abbreviations
path = '../sarah/google_trends/statesAbbrev.csv'
statesAbbrev_df = pd.read_csv(path)
statesAbbrev_df.tail(12)
# Out:
#              State Abbrev Code
# 39    Rhode Island   R.I.   RI
# 40  South Carolina   S.C.   SC
# 41    South Dakota   S.D.   SD
# 42       Tennessee  Tenn.   TN
# 43           Texas   Tex.   TX
# 44            Utah   Utah   UT
# 45         Vermont    Vt.   VT
# 46        Virginia    Va.   VA
# 47      Washington  Wash.   WA
# 48   West Virginia  W.Va.   WV
# 49       Wisconsin   Wis.   WI
# 50         Wyoming   Wyo.   WY

# %%
#list for state codes
state_codes = [x for x in statesAbbrev_df['Code']]

# %%
#creating a df dict to hold the state dfs, reading in the dfs
states_df_dict = {}
for x in range(40, 51):
    path = f'../sarah/google_trends/google_trends_csvs/state_csvs/US-{state_codes[x]}_cat_data.csv'
    states_df_dict[f'{state_codes[x]}_data_df'] = [pd.read_csv(path)]

# %%
#inspecting the keys (ie df names)
states_df_dict.keys()
# Out:
# dict_keys(['SC_data_df', 'SD_data_df', 'TN_data_df', 'TX_data_df', 'UT_data_df', 'VT_data_df', 'VA_data_df', 'WA_data_df', 'WV_data_df', 'WI_data_df', 'WY_data_df'])

# %%
#test printing a df
print(state_codes[40])
states_df_dict[f'{state_codes[40]}_data_df'][0].head(10)
# Out:
# SC
#          time  arts_entertainment  autos  beauty_fitness  books_lit  \
# 0  2019-01-06                  96     78              70         87
# 1  2019-01-13                  95     76              73         87
# 2  2019-01-20                  88     80              71         81
# 3  2019-01-27                  93     76              70         83
# 4  2019-02-03                  92     78              72         88
# 5  2019-02-10                  95     80              68         92
# 6  2019-02-17                  95     82              76         90
# 7  2019-02-24                 100     84              73         94
# 8  2019-03-03                  97     82              72         93
# 9  2019-03-10                  93     83              68         86
#
#    action_adventure  campaigns_elections  celebs  discrimination  \
# 0                68                    0      65              22
# 1                74                    0      66              10
# 2                69                    0      61              18
# 3                71                    0      66              17
# 4                65                    0      61              26
# 5                58                    0      63              20
# 6                66                    0      78              23
# 7                64                    0      69              25
# 8                63                    0      59              46
# 9                55                    0      68              22
#
#    entertainment_media  ...  mobiles  online_vids  scifi_fantasy  sport_news  \
# 0                   68  ...       60           92             66          80
# 1                   83  ...       61           87             54          48
# 2                   73  ...       62           83             55          54
# 3                   80  ...       61           94             43          44
# 4                   60  ...       61           81             42          73
# 5                   72  ...       64           91             51          47
# 6                   67  ...       67           91             40          40
# 7                   68  ...       64           87             55          45
# 8                   75  ...       70           89             51          39
# 9                   66  ...       64           84             46          63
#
#    tv_shows  voice_vid_chat  weather  covid_cases  stay_at_home  \
# 0        91              37       59          NaN         False
# 1        79              35       68          NaN         False
# 2        89              41       68          NaN         False
# 3        83              48       69          NaN         False
# 4        89              58       57          NaN         False
# 5        78              43       70          NaN         False
# 6        83              53       80          NaN         False
# 7        86              70       74          NaN         False
# 8        91              52       76          NaN         False
# 9        84              55       58          NaN         False
#
#    mass_gathering_ban
# 0               False
# 1               False
# 2               False
# 3               False
# 4               False
# 5               False
# 6               False
# 7               False
# 8               False
# 9               False
#
# [10 rows x 25 columns]

# %%
col_names = list(states_df_dict[f'{state_codes[40]}_data_df'][0].columns)

# %%
col_names_for_max = [x for x in col_names if x not in ['time', 'covid_cases', 'stay_at_home', 'mass_gathering_ban']]

# %%
times_list = list(states_df_dict[f'{state_codes[40]}_data_df'][0]['time'])

# %%
times_list
# Out:
# ['2019-01-06',
#  '2019-01-13',
#  '2019-01-20',
#  '2019-01-27',
#  '2019-02-03',
#  '2019-02-10',
#  '2019-02-17',
#  '2019-02-24',
#  '2019-03-03',
#  '2019-03-10',
#  '2019-03-17',
#  '2019-03-24',
#  '2019-03-31',
#  '2019-04-07',
#  '2019-04-14',
#  '2019-04-21',
#  '2019-04-28',
#  '2019-05-05',
#  '2019-05-12',
#  '2019-05-19',
#  '2019-05-26',
#  '2019-06-02',
#  '2019-06-09',
#  '2019-06-16',
#  '2019-06-23',
#  '2019-06-30',
#  '2019-07-07',
#  '2019-07-14',
#  '2019-07-21',
#  '2019-07-28',
#  '2019-08-04',
#  '2019-08-11',
#  '2019-08-18',
#  '2019-08-25',
#  '2019-09-01',
#  '2019-09-08',
#  '2019-09-15',
#  '2019-09-22',
#  '2019-09-29',
#  '2019-10-06',
#  '2019-10-13',
#  '2019-10-20',
#  '2019-10-27',
#  '2019-11-03',
#  '2019-11-10',
#  '2019-11-17',
#  '2019-11-24',
#  '2019-12-01',
#  '2019-12-08',
#  '2019-12-15',
#  '2019-12-22',
#  '2019-12-29',
#  '2020-01-05',
#  '2020-01-12',
#  '2020-01-19',
#  '2020-01-26',
#  '2020-02-02',
#  '2020-02-09',
#  '2020-02-16',
#  '2020-02-23',
#  '2020-03-01',
#  '2020-03-08',
#  '2020-03-15',
#  '2020-03-22',
#  '2020-03-29',
#  '2020-04-05',
#  '2020-04-12',
#  '2020-04-19',
#  '2020-04-26',
#  '2020-05-03',
#  '2020-05-10',
#  '2020-05-17',
#  '2020-05-24',
#  '2020-05-31',
#  '2020-06-07',
#  '2020-06-14',
#  '2020-06-21',
#  '2020-06-28',
#  '2020-07-05',
#  '2020-07-12',
#  '2020-07-19',
#  '2020-07-26',
#  '2020-08-02',
#  '2020-08-09',
#  '2020-08-16',
#  '2020-08-23',
#  '2020-08-30',
#  '2020-09-06',
#  '2020-09-13',
#  '2020-09-20',
#  '2020-09-27',
#  '2020-10-04',
#  '2020-10-11',
#  '2020-10-18',
#  '2020-10-25',
#  '2020-11-01',
#  '2020-11-08',
#  '2020-11-15',
#  '2020-11-22',
#  '2020-11-29',
#  '2020-12-06',
#  '2020-12-13',
#  '2020-12-20']

# %%
def boxplot_printer(ind_no):
    all_data_df = states_df_dict[f'{state_codes[ind_no]}_data_df'][0]
    data_2019_df = all_data_df.iloc[:52, :]
    data_2020_df = all_data_df.iloc[52:, :]
    
    ax = test_df.boxplot(column=col_names_for_max, rot=65, figsize=(20,10))

    plt.title(f'2019+2020 data for {state_codes[ind_no]}')
    plt.xlabel('category')
    plt.ylabel('popularity(%)')
    plt.show()
    
    ax = data_2019_df.boxplot(column=col_names_for_max, rot=65, figsize=(20,10))

    plt.title(f'2019 data for {state_codes[ind_no]}')
    plt.xlabel('category')
    plt.ylabel('popularity(%)')
    plt.show()
    
    ax = data_2020_df.boxplot(column=col_names_for_max, rot=65, figsize=(20,10))

    plt.title(f'2020 data for {state_codes[ind_no]}')
    plt.xlabel('category')
    plt.ylabel('popularity(%)')
    plt.show()

# %%
boxplot_printer(44)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-0db594d2e1e2> in <module>
# ----> 1 boxplot_printer(44)
#
# <ipython-input-22-f9831157d621> in boxplot_printer(ind_no)
#       4     data_2020_df = all_data_df.iloc[52:, :]
#       5
# ----> 6     ax = test_df.boxplot(column=col_names_for_max, rot=65, figsize=(20,10))
#       7
#       8     plt.title(f'2019+2020 data for {state_codes[ind_no]}')
#
# NameError: name 'test_df' is not defined
