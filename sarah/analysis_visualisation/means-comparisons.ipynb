# %%
#dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
from matplotlib.lines import Line2D

# %%
#reading in the state abbreviations
path = '../google_trends/statesAbbrev.csv'
statesAbbrev_df = pd.read_csv(path)
statesAbbrev_df.tail(12)
# Out:
#              State Abbrev Code
# 39    Rhode Island   R.I.   RI
# 40  South Carolina   S.C.   SC
# 41    South Dakota   S.D.   SD
# 42       Tennessee  Tenn.   TN
# 43           Texas   Tex.   TX
# 44            Utah   Utah   UT
# 45         Vermont    Vt.   VT
# 46        Virginia    Va.   VA
# 47      Washington  Wash.   WA
# 48   West Virginia  W.Va.   WV
# 49       Wisconsin   Wis.   WI
# 50         Wyoming   Wyo.   WY

# %%
#list for state codes
state_codes = [x for x in statesAbbrev_df['Code']]

# %%
#list for state names
state_names = [x for x in statesAbbrev_df['State']]

# %%
#creating a df dict to hold the state dfs, reading in the dfs
states_df_dict = {}
for x in range(40, 51):
    path = f'../google_trends/google_trends_csvs/state_csvs/US-{state_codes[x]}_cat_data.csv'
    states_df_dict[f'{state_codes[x]}_data_df'] = [pd.read_csv(path)]

# %%
#inspecting the keys (ie df names)
states_df_dict.keys()
# Out:
# dict_keys(['SC_data_df', 'SD_data_df', 'TN_data_df', 'TX_data_df', 'UT_data_df', 'VT_data_df', 'VA_data_df', 'WA_data_df', 'WV_data_df', 'WI_data_df', 'WY_data_df'])

# %%
#test printing a df
print(state_codes[40])
states_df_dict[f'{state_codes[40]}_data_df'][0].head(10)
# Out:
# SC
#          time  arts_entertainment  autos  beauty_fitness  books_lit  \
# 0  2019-01-06                  96     78              70         87
# 1  2019-01-13                  95     76              73         87
# 2  2019-01-20                  88     80              71         81
# 3  2019-01-27                  93     76              70         83
# 4  2019-02-03                  92     78              72         88
# 5  2019-02-10                  95     80              68         92
# 6  2019-02-17                  95     82              76         90
# 7  2019-02-24                 100     84              73         94
# 8  2019-03-03                  97     82              72         93
# 9  2019-03-10                  93     83              68         86
#
#    action_adventure  campaigns_elections  celebs  discrimination  \
# 0                68                    0      65              22
# 1                74                    0      66              10
# 2                69                    0      61              18
# 3                71                    0      66              17
# 4                65                    0      61              26
# 5                58                    0      63              20
# 6                66                    0      78              23
# 7                64                    0      69              25
# 8                63                    0      59              46
# 9                55                    0      68              22
#
#    entertainment_media  ...  mobiles  online_vids  scifi_fantasy  sport_news  \
# 0                   68  ...       60           92             66          80
# 1                   83  ...       61           87             54          48
# 2                   73  ...       62           83             55          54
# 3                   80  ...       61           94             43          44
# 4                   60  ...       61           81             42          73
# 5                   72  ...       64           91             51          47
# 6                   67  ...       67           91             40          40
# 7                   68  ...       64           87             55          45
# 8                   75  ...       70           89             51          39
# 9                   66  ...       64           84             46          63
#
#    tv_shows  voice_vid_chat  weather  covid_cases  stay_at_home  \
# 0        91              37       59          NaN         False
# 1        79              35       68          NaN         False
# 2        89              41       68          NaN         False
# 3        83              48       69          NaN         False
# 4        89              58       57          NaN         False
# 5        78              43       70          NaN         False
# 6        83              53       80          NaN         False
# 7        86              70       74          NaN         False
# 8        91              52       76          NaN         False
# 9        84              55       58          NaN         False
#
#    mass_gathering_ban
# 0               False
# 1               False
# 2               False
# 3               False
# 4               False
# 5               False
# 6               False
# 7               False
# 8               False
# 9               False
#
# [10 rows x 25 columns]

# %%
col_names = list(states_df_dict[f'{state_codes[40]}_data_df'][0].columns)

# %%
col_names_for_max = [x for x in col_names if x not in ['time', 'covid_cases', 'stay_at_home', 'mass_gathering_ban']]

# %%
times_list = list(states_df_dict[f'{state_codes[40]}_data_df'][0]['time'])

# %%
for x in range(40, 51):
    for y in range(1, len(states_df_dict[f'{state_codes[x]}_data_df'])):
        del(states_df_dict[f'{state_codes[x]}_data_df'][y])
    print(state_codes[x])
    print(len(states_df_dict[f'{state_codes[x]}_data_df']))
# Out:
# SC
# 1
# SD
# 1
# TN
# 1
# TX
# 1
# UT
# 1
# VT
# 1
# VA
# 1
# WA
# 1
# WV
# 1
# WI
# 1
# WY
# 1

# %%
def means_comp(ind_no):
    all_data_df = states_df_dict[f'{state_codes[ind_no]}_data_df'][0]
    data_2019_df = all_data_df.iloc[:52, :]
    data_2020_df = all_data_df.iloc[52:, :]
    
    means_diff = []
    for col in col_names_for_max:
        means_diff_instance = stats.ttest_ind(data_2019_df[col], data_2020_df[col], equal_var=False)[1]
        means_diff.append(means_diff_instance)
    means_diff[21:24] = 'n/a', 'n/a', 'n/a'
    
    signif_list = []
    for x in means_diff:
        if x == 'n/a':
            signif_list.append('n/a')
        elif x <= 0.05:
            signif_list.append('Yes')
        elif x > 0.05:
            signif_list.append('No')

    comparison_df = pd.DataFrame({'categories': data_2019_df.mean().index, '2019_means': data_2019_df.mean().values, '2020_means': data_2020_df.mean().values, 'p_vals': means_diff, 'stats_signif': signif_list})
    comparison_df.drop([21,22,23], inplace=True)
    comparison_df.set_index('categories', inplace=True)
    new_index = ['action_adventure', 'scifi_fantasy', 'tv_shows', 'online_vids', 'mobiles', 'voice_vid_chat', 'infectious_diseases', 'health_news', 'games_systems_consoles', 'arts_entertainment', 'books_lit', 'lottos', 'celebs', 'entertainment_media', 'campaigns_elections', 'discrimination', 'law_enf', 'weather', 'autos', 'beauty_fitness', 'sport_news']
    comparison_df = comparison_df.reindex(new_index)
    states_df_dict[f'{state_codes[ind_no]}_data_df'].append(comparison_df)
    
    signif_cats =[]
    for x in range(0, len(comparison_df)):
        if comparison_df.iloc[x, 3] == 'Yes':
            signif_cats.append((list(comparison_df.index)[x], comparison_df.iloc[x, 2]))
    states_df_dict[f'{state_codes[ind_no]}_data_df'].append(signif_cats)

# %%
for x in range(40, 51):
    means_comp(x)

# %%
print(state_codes[49])
means_meds_df = states_df_dict[f'{state_codes[49]}_data_df'][1]
means_meds_df
# Out:
# WI
#                         2019_means  2020_means       p_vals stats_signif
# categories
# action_adventure         67.076923   67.078431     0.999225           No
# scifi_fantasy            54.557692   60.490196    0.0363816          Yes
# tv_shows                 80.384615   77.647059    0.0626203           No
# online_vids              83.076923   76.941176   3.9618e-05          Yes
# mobiles                  65.076923   59.803922  0.000564451          Yes
# voice_vid_chat           41.615385   38.411765     0.260876           No
# infectious_diseases       7.250000   20.725490  2.92265e-06          Yes
# health_news              44.826923   52.392157   0.00960556          Yes
# games_systems_consoles   48.961538   56.568627  0.000665709          Yes
# arts_entertainment       90.173077   83.725490   1.3864e-08          Yes
# books_lit                77.000000   69.627451   0.00411761          Yes
# lottos                   41.730769   35.686275  0.000514207          Yes
# celebs                   60.115385   66.784314  0.000140244          Yes
# entertainment_media      68.846154   68.450980     0.834072           No
# campaigns_elections       0.153846    3.039216     0.145498           No
# discrimination           23.865385   29.450980    0.0219306          Yes
# law_enf                  49.923077   53.058824     0.140456           No
# weather                  43.884615   38.352941    0.0227027          Yes
# autos                    72.903846   67.745098   0.00315202          Yes
# beauty_fitness           78.865385   75.843137   0.00799597          Yes
# sport_news               62.769231   43.921569  1.02665e-11          Yes

# %%
states_df_dict[f'{state_codes[49]}_data_df'][2]
# Out:
# [('scifi_fantasy', 0.03638155101062401),
#  ('online_vids', 3.961799496019733e-05),
#  ('mobiles', 0.0005644508870334183),
#  ('infectious_diseases', 2.9226481069975736e-06),
#  ('health_news', 0.009605562021610666),
#  ('games_systems_consoles', 0.000665709128181784),
#  ('arts_entertainment', 1.386402826914742e-08),
#  ('books_lit', 0.004117605812143661),
#  ('lottos', 0.0005142065561865732),
#  ('celebs', 0.00014024411608071764),
#  ('discrimination', 0.02193062856392299),
#  ('weather', 0.02270266117185006),
#  ('autos', 0.00315201959296557),
#  ('beauty_fitness', 0.007995966611744162),
#  ('sport_news', 1.0266544809071982e-11)]

# %%
for x in range(40, 51):
    print(state_codes[x])
    print(states_df_dict[f'{state_codes[x]}_data_df'][2])
# Out:
# SC
# [('action_adventure', 0.037213368887122865), ('scifi_fantasy', 0.020561479597784815), ('tv_shows', 0.001723158935242587), ('online_vids', 8.082991587792804e-10), ('infectious_diseases', 8.313448149762176e-06), ('health_news', 8.172355066885259e-05), ('games_systems_consoles', 2.2536372559833473e-06), ('arts_entertainment', 1.1386869137802196e-05), ('books_lit', 0.0036629705074250007), ('lottos', 5.164235097920391e-06), ('celebs', 2.0464965258284322e-05), ('entertainment_media', 0.0409192335375911), ('discrimination', 0.0006658984716343508), ('sport_news', 1.2060797821829332e-10)]
# SD
# [('action_adventure', 0.02517127820578754), ('scifi_fantasy', 0.00842259325095429), ('tv_shows', 0.012613457326598672), ('online_vids', 0.027560319692913875), ('infectious_diseases', 3.6849899850973405e-06), ('arts_entertainment', 0.0026597091290213636), ('books_lit', 0.0005535286715042026), ('lottos', 0.0005213150936593188), ('celebs', 0.0007263319652055333), ('discrimination', 0.01967980766116836), ('weather', 0.027323769701489583), ('sport_news', 2.2995958068710177e-05)]
# TN
# [('tv_shows', 2.131424371522241e-06), ('online_vids', 2.2152967856265378e-10), ('mobiles', 0.0010491511185653488), ('voice_vid_chat', 0.0011882179518047649), ('infectious_diseases', 1.976083580578135e-05), ('health_news', 0.03823531527551938), ('games_systems_consoles', 0.0029585385323761875), ('arts_entertainment', 1.787492558835714e-11), ('books_lit', 0.0006382836800782082), ('lottos', 3.4978861562129475e-11), ('celebs', 0.020364287276221634), ('discrimination', 0.002022912796452022), ('autos', 0.0013526525392755482), ('sport_news', 3.734104670468228e-09)]
# TX
# [('action_adventure', 0.003860099817519732), ('tv_shows', 2.8191158001375033e-05), ('mobiles', 0.016680135123175517), ('voice_vid_chat', 0.019768372750786266), ('infectious_diseases', 2.429295981282172e-06), ('health_news', 0.00010210706141703811), ('games_systems_consoles', 1.1535830141696121e-05), ('arts_entertainment', 5.917353475659791e-12), ('books_lit', 0.020787453885561493), ('lottos', 2.3615688954881266e-08), ('celebs', 0.04442561736621344), ('discrimination', 0.003685766942499048), ('autos', 0.0009053970605513475), ('beauty_fitness', 0.019352346290415334), ('sport_news', 7.150056005110144e-15)]
# UT
# [('scifi_fantasy', 0.013011109382559106), ('online_vids', 0.023179426954940945), ('mobiles', 0.03448612449528127), ('infectious_diseases', 7.747204101807411e-06), ('games_systems_consoles', 0.001574819157516452), ('arts_entertainment', 4.604231997520307e-08), ('books_lit', 0.007882721005095987), ('lottos', 3.011194436159994e-06), ('celebs', 0.0036656842096455654), ('entertainment_media', 0.04029204226319482), ('discrimination', 0.003057377906500814), ('weather', 0.02236036401610036), ('sport_news', 7.802649973900028e-07)]
# VT
# [('scifi_fantasy', 0.01282378178352018), ('online_vids', 0.007671321758829178), ('infectious_diseases', 1.2798049442020326e-06), ('games_systems_consoles', 0.0039330676751393135), ('books_lit', 0.014500280797163345), ('lottos', 3.7420623029720037e-05), ('celebs', 3.249917084598795e-05), ('discrimination', 0.03904405662366935), ('sport_news', 0.0002846767177331197)]
# VA
# [('tv_shows', 8.200870111122177e-06), ('online_vids', 9.181515568234888e-08), ('mobiles', 0.003992054457736524), ('infectious_diseases', 5.64246896031666e-06), ('health_news', 0.011309214508895264), ('games_systems_consoles', 2.6670196612890076e-05), ('arts_entertainment', 2.4745260988313054e-13), ('books_lit', 2.7108620342276726e-06), ('lottos', 8.449623355480037e-16), ('celebs', 0.003170364661130704), ('discrimination', 0.008130420641656148), ('autos', 0.0002151497466402287), ('beauty_fitness', 0.008259869764160975), ('sport_news', 1.4655567989969214e-13)]
# WA
# [('mobiles', 0.0005847172934776497), ('infectious_diseases', 2.174571842790142e-06), ('games_systems_consoles', 4.106847547145226e-05), ('arts_entertainment', 1.50534956333137e-09), ('books_lit', 0.005947425511733981), ('lottos', 9.551400525440147e-08), ('celebs', 0.0012031198344436911), ('discrimination', 0.0076783405730117766), ('autos', 0.0010208294992710466), ('beauty_fitness', 3.21051017386855e-05), ('sport_news', 4.8876919897244976e-12)]
# WV
# [('scifi_fantasy', 0.03431710796679103), ('online_vids', 2.804245273049256e-06), ('infectious_diseases', 9.921381638859162e-06), ('health_news', 0.0058614068627625875), ('games_systems_consoles', 0.00015057995520919247), ('arts_entertainment', 0.007200477636542969), ('books_lit', 0.04787426439764605), ('lottos', 0.0006425951077662763), ('celebs', 0.00044921345304713687), ('discrimination', 0.005483657068579233), ('sport_news', 2.1633845351903713e-05)]
# WI
# [('scifi_fantasy', 0.03638155101062401), ('online_vids', 3.961799496019733e-05), ('mobiles', 0.0005644508870334183), ('infectious_diseases', 2.9226481069975736e-06), ('health_news', 0.009605562021610666), ('games_systems_consoles', 0.000665709128181784), ('arts_entertainment', 1.386402826914742e-08), ('books_lit', 0.004117605812143661), ('lottos', 0.0005142065561865732), ('celebs', 0.00014024411608071764), ('discrimination', 0.02193062856392299), ('weather', 0.02270266117185006), ('autos', 0.00315201959296557), ('beauty_fitness', 0.007995966611744162), ('sport_news', 1.0266544809071982e-11)]
# WY
# [('tv_shows', 0.003564403911922712), ('online_vids', 0.011161572055350935), ('infectious_diseases', 1.9116629466131967e-05), ('games_systems_consoles', 0.009817608796413819), ('arts_entertainment', 0.000299478163159776), ('books_lit', 0.009342488939380368), ('lottos', 0.035131713792526664), ('celebs', 0.008825692307801296), ('discrimination', 0.014241283636668444), ('weather', 0.011661769472952353), ('sport_news', 0.0007746388157160955)]

# %%
states_df_dict[f'{state_codes[43]}_data_df'][0].describe()
# Out:
#        arts_entertainment       autos  beauty_fitness   books_lit  \
# count          103.000000  103.000000      103.000000  103.000000
# mean            88.058252   74.203883       82.990291   72.766990
# std              4.993771    7.238729        5.427770   12.717291
# min             73.000000   59.000000       64.000000   50.000000
# 25%             86.000000   70.000000       80.000000   60.500000
# 50%             89.000000   73.000000       84.000000   76.000000
# 75%             91.000000   78.000000       87.000000   82.000000
# max            100.000000  100.000000      100.000000  100.000000
#
#        action_adventure  campaigns_elections      celebs  discrimination  \
# count        103.000000           103.000000  103.000000      103.000000
# mean          71.077670             1.640777   59.621359       26.135922
# std            6.776096             9.871582    8.439074       13.357856
# min           59.000000             0.000000   47.000000       12.000000
# 25%           67.000000             0.000000   54.000000       19.500000
# 50%           70.000000             0.000000   58.000000       22.000000
# 75%           74.500000             1.000000   63.000000       27.500000
# max          100.000000           100.000000  100.000000      100.000000
#
#        entertainment_media  games_systems_consoles  ...     law_enf  \
# count           103.000000              103.000000  ...  103.000000
# mean             73.611650               59.699029  ...   51.796117
# std               8.191618               12.109658  ...    8.018800
# min              50.000000               44.000000  ...   41.000000
# 25%              69.000000               51.000000  ...   48.000000
# 50%              73.000000               54.000000  ...   51.000000
# 75%              77.000000               66.000000  ...   54.000000
# max             100.000000              100.000000  ...  100.000000
#
#            lottos     mobiles  online_vids  scifi_fantasy  sport_news  \
# count  103.000000  103.000000   103.000000      103.00000  103.000000
# mean    50.922330   56.747573    72.902913       56.07767   68.796117
# std      8.549383    7.306616     7.716184       13.40814   16.417565
# min     39.000000   47.000000    60.000000       42.00000   36.000000
# 25%     45.000000   53.000000    67.000000       48.00000   59.000000
# 50%     50.000000   55.000000    73.000000       51.00000   73.000000
# 75%     54.500000   57.500000    77.000000       59.00000   80.500000
# max    100.000000  100.000000   100.000000      100.00000  100.000000
#
#          tv_shows  voice_vid_chat     weather   covid_cases
# count  103.000000      103.000000  103.000000  4.200000e+01
# mean    80.038835       64.000000   57.058252  4.882163e+05
# std      5.269078       10.875408   17.638430  4.725259e+05
# min     63.000000       44.000000   24.000000  5.000000e+00
# 25%     77.000000       56.500000   44.000000  4.967500e+04
# 50%     80.000000       63.000000   57.000000  4.091835e+05
# 75%     83.000000       69.000000   70.000000  7.858320e+05
# max    100.000000      100.000000  100.000000  1.581668e+06
#
# [8 rows x 22 columns]

# %% [markdown]
# #### Guide to indices w/in states_df_dict:
#
# index 0 is a df containing all info on a state (the categs info, the covid cases, the stay at home orders/gathering bans)
#
# index 1 is a df showing the average pop rating for each category in 2019 and 2020, and the p value of an indep t-test for each categ, and whether the p-val is signif
#
# index 2 is a list of all the cats w/ signif changes in cat pop, and their p-vals
