# %%
import requests
import json
import pandas as pd
from pytrends.request import TrendReq

pytrends = TrendReq(hl='en-US', tz=360)

# %%
state =[
        'AL','AK','AZ','AR','CA','CO','CT','DE','FL','GA','HI','ID','IL','IN','IA','KS','KY',
        'LA','ME','MD','MA','MI','MN','MS','MO','MT','NE','NV','NH','NJ','NM','NY','NC','ND',
        'OH','OK','OR','PA','RI','SC','SD','TN','TX','UT','VT','VA','WA','WV','WI','WY'
        ]

# %%
# getting length of list
# length = len(state)
  
# Iterating the index
# same as 'for x in range(len(list))'
for x in range(0, 50):
    api = 'https://api.covidtracking.com/v1/states/'+state[x]+'/current.json'
#     print(api)
    r = requests.get(api)
    rj = r.json()
# print("ok",rj['state'])
# jsonVal = r.text    
# print("hello",jsonVal) 
    print("Covid19 Effect by states:")
    print("State Name:",rj['state']," Positive cases:",rj['positive']," Death:",rj['death'])
# Out:
# Covid19 Effect by states:
# State Name: AL  Positive cases: 345628  Death: 4691
# Covid19 Effect by states:
# State Name: AK  Positive cases: 44280  Death: 200
# Covid19 Effect by states:
# State Name: AZ  Positive cases: 494337  Death: 8427
# Covid19 Effect by states:
# State Name: AR  Positive cases: 214877  Death: 3482
# Covid19 Effect by states:
# State Name: CA  Positive cases: 2122806  Death: 24220
# Covid19 Effect by states:
# State Name: CO  Positive cases: 325018  Death: 4610
# Covid19 Effect by states:
# State Name: CT  Positive cases: 172743  Death: 5791
# Covid19 Effect by states:
# State Name: DE  Positive cases: 55057  Death: 897
# Covid19 Effect by states:
# State Name: FL  Positive cases: 1250275  Death: 21514
# Covid19 Effect by states:
# State Name: GA  Positive cases: 543707  Death: 10689
# Covid19 Effect by states:
# State Name: HI  Positive cases: 21418  Death: 285
# Covid19 Effect by states:
# State Name: ID  Positive cases: 135787  Death: 1354
# ...

# %%
payload = {'key1': 'value1', 'key2': ['value2', 'value3']}
r = requests.get('https://api.covidtracking.com/v1/states/ca/info.json', params=payload)
print('URL: ', r.url)
print('HEADERS: ', r.headers)
# for STATES in r: 
print('TEXT: ', r.json)
# Out:
# URL:  https://api.covidtracking.com/v1/states/ca/info.json?key1=value1&key2=value2&key2=value3
# HEADERS:  {'Accept-Ranges': 'bytes', 'Access-Control-Allow-Origin': '*', 'Cache-Control': 'public, max-age=0, must-revalidate', 'Content-Type': 'application/json', 'Date': 'Mon, 28 Dec 2020 11:57:47 GMT', 'Etag': '"ace746e951b03460f238093da7cb08d2-ssl-df"', 'Strict-Transport-Security': 'max-age=31536000', 'Content-Encoding': 'gzip', 'Content-Length': '1306', 'Age': '0', 'Connection': 'keep-alive', 'Server': 'Netlify', 'Vary': 'Accept-Encoding', 'X-NF-Request-ID': '1e5ddd69-621d-49d2-a4cc-2d53f44dca63-72780676'}
# TEXT:  <bound method Response.json of <Response [200]>>

# %%
pytrends.trending_searches(pn='united_states')
# Out:
#                          0
# 0            Brooklyn Nets
# 1                  Packers
# 2                 Steelers
# 3       Kansas City Chiefs
# 4                 Clippers
# 5          Hilaria Baldwin
# 6           Dwayne Haskins
# 7                   Lakers
# 8                  Broncos
# 9                  Bengals
# 10     AFC playoff picture
# 11             Phil Niekro
# 12  Liverpool vs West Brom
# 13           Masked Dancer
# 14                 Celtics
# 15        Nashville bomber
# 16            Kevin Greene
# 17           Death to 2020
# 18           Carrie Fisher
# 19     Wolves vs Tottenham

# %%
#cat_list = [184, 1116, 891, 1097, 1291, 1325, 655, 466, 467, 1203]

# %%
cat_list ={ "Celebrities & Entertainment News": 184, "Film & TV Industry": 1116, "Concerts & Music Festivals": 891,
            "Guitars": 1325, "Industrial & Product Design": 655, "Home Financing": 466,"Auto Insurance": 467,
            "Media Critics & Watchdogs": 1203}
